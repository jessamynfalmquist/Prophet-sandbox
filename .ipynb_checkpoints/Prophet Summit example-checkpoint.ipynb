# %%
# Here is an example looking at a time series of daily page views for the Wikipedia page for Peyton Manning

# %%
# packages
import pandas as pd
import numpy as np
from fbprophet import Prophet

# %%
# Import the data
df = pd.read_csv('C:/Users/Jessamy Almquist/Documents/GitHub/Prophet-sandbox/one-off_data-query_4-2bf7575aa424-2017-05-01-17-12-51.csv')

## log-transform the y variable
#df['y'] = np.log(df['y'])
#
# check out a sample 
df.head()
# Out:
#         as_of                          use_name  site_id state      city  \
# 0  2017-05-01                 AZ Kelsey Academy      129    GA   Griffin
# 1  2017-05-01             AZ Kelsey Achievement      128    GA  Griffin
# 2  2017-05-01                 Academy of Choice      134    TX   Houston
# 3  2017-05-01      Aire Libre Elementary School      178    AZ   Phoenix
# 4  2017-05-01  Alexander Rose Elementary School      164    CA  Milpitas
#
#                  region basecamp_mentor  no_of_grades   type_of_school  \
# 0             Southeast           Susan             1  Public District
# 1             Southeast           Susan             2  Public District
# 2           Gulf Region           Susan             1  Public District
# 3  SoCal/AZ/Central Cal          Arelys             1  Public District
# 4                NorCal           Samia             1  Public District
#
#    map_name      ...       sped_population  sped_category  alternative_school  \
# 0       NaN      ...                   NaN            NaN                True
# 1       NaN      ...                   NaN            NaN                True
# 2       NaN      ...                   1.0            NaN               False
# 3       NaN      ...                  25.0           High               False
# 4       NaN      ...                   8.0            NaN               False
#
#    partner_tableau_email   id still_in_program  zip_code cohort_number  \
# 0                    NaN   93            False       NaN           NaN
# 1                    NaN   92            False       NaN           NaN
# 2                    NaN   96             True   77055.0           2.0
# 3                    NaN  130             True   85022.0           2.0
# 4                    NaN  117             True   95035.0           2.0
#
#    deprecated_glt_cohort_3 deprecated_itu
# 0                      NaN            NaN
# 1                      NaN            NaN
# 2                      NaN            NaN
# 3                      NaN            NaN
# 4                      NaN            NaN
#
# [5 rows x 30 columns]

# %%
# We fit the model by instantiating a new Prophet object. 
# Any settings to the forecasting procedure are passed into the constructor. 
m = Prophet()

# Then you call its fit method and pass in the historical dataframe. Fitting should take 1-5 seconds.
m.fit(df);

# %%
# Predictions are then made on a dataframe with a column ds containing the dates for which a prediction is to be made. 

# You can get a suitable dataframe that extends into the future a specified number of days using the helper method Prophet.make_future_dataframe. 
# By default it will also include the dates from the history, so we will see the model fit as well.
future = m.make_future_dataframe(periods=365)

# check out a sample (from the end)
future.tail()
# Out:
#              ds
# 3265 2017-01-15
# 3266 2017-01-16
# 3267 2017-01-17
# 3268 2017-01-18
# 3269 2017-01-19

# %%
# The predict method will assign each row in future a predicted value which it names yhat. 
# If you pass in historical dates, it will provide an in-sample fit. 
# The forecast object here is a new dataframe that includes a column yhat with the forecast, as well as columns for components and uncertainty intervals.
forecast = m.predict(future)

# check out a sample (from the end)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 3265 2017-01-15  8.199561    7.434913    8.903349
# 3266 2017-01-16  8.524560    7.789667    9.260038
# 3267 2017-01-17  8.311920    7.599936    9.053540
# 3268 2017-01-18  8.144517    7.354237    8.842646
# 3269 2017-01-19  8.156377    7.446545    8.881490

# %%
# You can plot the forecast by calling the Prophet.plot method and passing in your forecast dataframe.
m.plot(forecast)

# %%
# If you want to see the forecast components, you can use the Prophet.plot_components method. By default you’ll see the trend, yearly seasonality, and weekly seasonality of the time series. 
# If you include holidays, you’ll see those here, too.
# Note: I'm not sure what it means to "include holidays"
m.plot_components(forecast)
